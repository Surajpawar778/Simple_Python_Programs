# %% [markdown]
# <a href="https://colab.research.google.com/github/Surajpawar778/Simple_Python_Programs/blob/main/assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###1. Generate a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = 0
std_dev = 0.5
size = 100

data = np.random.normal(mean, std_dev, size)
print(data)
plt.hist(data, bins=15,edgecolor ="black")
plt.title("Histogram of Normal Distribution")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# [-2.61949779e-01 -2.79620329e-01 -1.75449056e-01  6.34211766e-02
#   3.15761068e-01  1.10081934e-01 -3.41947478e-01  2.20487340e-02
#  -7.18673325e-02  2.57733686e-01 -1.03837786e-01  3.70877898e-01
#  -1.03943504e+00  6.05116980e-01 -5.68333398e-01 -2.46221923e-01
#   2.19224675e-01 -7.66249457e-01  2.86477328e-02 -3.24457750e-01
#  -1.21263663e-02  6.58809028e-01 -4.65457405e-01 -3.13430477e-01
#  -2.55622013e-01 -8.45616787e-01  2.49913293e-01  3.17340657e-01
#  -5.90552997e-01 -7.88641157e-01  3.20109292e-01  7.91115138e-01
#  -4.50394064e-01 -2.92372817e-01 -3.93420090e-01 -3.84755297e-02
#   5.97866908e-01 -4.43747881e-04  1.04404076e-01  6.08793221e-01
#   3.31681017e-01  1.08942739e+00 -1.35741822e-01 -3.08759567e-01
#  -6.71834539e-01 -1.66952131e-01  4.25313323e-01  5.84197707e-01
#  -3.20265419e-01  3.71386426e-01  3.92004182e-01 -1.09772383e-01
#   1.71704072e-01 -6.86072056e-02  2.30422022e-01 -5.32966321e-01
#   1.03330044e+00  1.04990607e-01 -3.09680412e-01 -2.40439822e-01
#  -5.71524527e-01  4.80687195e-01 -5.66080710e-01  5.53863217e-01
#   2.22240641e-01 -8.54737967e-01 -5.99017789e-02 -6.21867731e-01
#   2.92278872e-02 -2.81629404e-01  5.70814852e-01  2.96435229e-01
#   9.55773089e-01  2.25442882e-02 -2.79965692e-01 -4.89736574e-01
#  -1.19998462e+00 -1.41145912e-01 -1.39679690e-01 -1.43187467e-02
#   2.60515529e-01 -3.25830106e-01  1.06379504e+00 -3.36403639e-01
#   3.81505473e-01 -6.54029443e-01 -1.33822991e-01  2.16767899e-01
#   2.41536612e-01  2.35905329e-01 -3.24611708e-01  8.57268187e-02
#  -3.26503819e-01 -7.62951362e-01  7.43390908e-01  7.07172059e-01
#  -2.81780255e-01 -4.40470713e-01 -1.69383775e-02 -4.14959765e-01]

# %% [markdown]
# ###2. Compute mean, median, variance, and standard deviation for a dataset.

# %%
data = [10, 20, 30, 40, 50]
n = len(data)

# Mean
mean = sum(data) / n

# Median
sorted_data = sorted(data)
if n % 2 == 0:
    median = (sorted_data[n//2 - 1] + sorted_data[n//2]) / 2
else:
    median = sorted_data[n//2]

# Variance (Population)
variance = sum((x - mean) ** 2 for x in data) / n

# Standard Deviation
std_dev = variance ** 0.5

print("Mean:", mean)
print("Median:", median)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 30.0
# Median: 30
# Variance: 200.0
# Standard Deviation: 14.142135623730951

# %% [markdown]
# ###3. Simulate a coin toss experiment and compute probabilities.

# %%
import random

# Number of tosses
n = int(input("Enter number of coin tosses: "))

heads = 0
tails = 0

for i in range(n):
    toss = random.choice(['H', 'T'])
    if toss == 'H':
        heads += 1
    else:
        tails += 1

# Probabilities
prob_heads = heads / n
prob_tails = tails / n

print("Total Heads:", heads)
print("Total Tails:", tails)
print("Probability of Heads:", prob_heads)
print("Probability of Tails:", prob_tails)
# Out:
# Enter number of coin tosses: 7
# Total Heads: 5
# Total Tails: 2
# Probability of Heads: 0.7142857142857143
# Probability of Tails: 0.2857142857142857
