# %% [markdown]
# <a href="https://colab.research.google.com/github/Surajpawar778/Simple_Python_Programs/blob/main/assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# **Normal Distribution**

# %%
#Generate 1000 random numbers from normal distribution
mean = 0
std_dev = 1

data = np.random.normal(mean, std_dev, 1000)

# Plot histogram
plt.hist(data, bins=30, density=True, alpha=0.6, color='skyblue')

# Plot theoretical normal curve
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = stats.norm.pdf(x, mean, std_dev)

plt.plot(x, p, 'r', linewidth=2)
plt.title("Normal Distribution")
plt.xlabel("Values")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# Descriptive **Statistics**

# %%
print("Mean:", np.mean(data))
print("Median:", np.median(data))
print("Variance:", np.var(data))
print("Standard Deviation:", np.std(data))
# Out:
# Mean: -0.02016877259325345
# Median: -0.009187953620432166
# Variance: 1.090917723689729
# Standard Deviation: 1.0444700683551105

# %% [markdown]
# Coin Toss **Simulation**

# %%
# Simulate 1000 coin tosses
tosses = np.random.choice(['H', 'T'], size=1000)

heads = np.sum(tosses == 'H')
tails = np.sum(tosses == 'T')

print("Number of Heads:", heads)
print("Number of Tails:", tails)
print("Probability of Heads:", heads/1000)
print("Probability of Tails:", tails/1000)
# Out:
# Number of Heads: 507
# Number of Tails: 493
# Probability of Heads: 0.507
# Probability of Tails: 0.493

# %% [markdown]
# Visualize Coin **Toss**

# %%
plt.bar(['Heads', 'Tails'], [heads, tails], color=['blue', 'orange'])
plt.title("Coin Toss Simulation")
plt.ylabel("Count")
plt.show()
